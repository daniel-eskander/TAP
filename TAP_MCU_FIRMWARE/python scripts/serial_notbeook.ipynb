# %%
import serial_listen
import importlib
importlib.reload(serial_listen)
received_values=serial_listen.listen("COM18",115200,100)
serial_listen.plot(received_values)
# Out:
# Listening on COM18 at 115200 baud rate.
# Frame 1: START_BYTE detected.
# ...
